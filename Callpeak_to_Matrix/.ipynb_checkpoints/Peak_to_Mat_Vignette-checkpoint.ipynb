# %% [markdown]
# # Chromatin Feature Generation Vignette
# ## This vignette details the steps of Peak Calling through (Cell-Feature) Matrix creation for snATAC-seq and multiome, with options for histome based chromatin assays

# %% [markdown]
# ## Steps:
# ### 01. Splitfrags
# ### 02. Peakcalling
# ### 03. PeakMerging
# ### 04. Matrix Generation

# %%
### 01. Split Frags 

### resources. by combinations 
### 8+ gigs per core, > cores greater speed (rec 20-40)
### Could just do ncores, with scaling for mem 

# Build kicker to launch with proper resources from this notebook with kicker template 
# Build support.py as splitfrags_support.py 

### Splitfrags Inputs 
### Provide inputs to this notebook, to configure kickers 
    # I1. User
    # I2. frag paths 
    # I3. Celltype column 
    # I4. Metadata with sample & barcode columns 
    # I5. Resources (Nodes:Cores) 



### ********* input 1 **********
user = 'rlancione'

### ********* input 2 **********
frag_paths = [
    "/tscc/projects/ps-epigen/10x_output/240813/counts_out/Multiome/QY_2579_QY_2578/outs/atac_fragments.tsv.gz",
    "/tscc/projects/ps-epigen/10x_output/240813/counts_out/Multiome/QY_2585_QY_2584/outs/atac_fragments.tsv.gz",
  
]

### ********* input 3 **********
celltype_col = 'celltype'

### ********* input 4 **********
metadata = pd.read_csv("hep_meta.csv", index_col=0)

### ********* input 5 **********
nodes_cores="1:20"

# %%
### argparse for support 
### TEMPLATE for split_args

# %%
### rest of notebook can run on notebook resources??

# %%
### Peak Calling-NB 

## add init-logging/ main func 
## to iterate over split frags in either parallel or linear 


### To then here declare:
    # 1. assay (ATAC, AC, ME3)
    # 2. parallel or not

# %%
### Peak Merging

# %%
### Matrix Generation
